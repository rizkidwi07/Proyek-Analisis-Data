# %% [markdown]
# # Proyek Analisis Data: [Input Nama Dataset]
# - **Nama:** Rizki Dwi Sya'bana Nugraha
# - **Email:** rizkidwi78@gmail.com
# - **ID Dicoding:** rizkidwi07

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Produk apa yang paling mahal dan paling murah?
# - Bagaimana penyebaran pelanggan berdasarkan kota dari e-commerce tersebut?
# - Kapan terakhir pelanggan melakukan transaksi?
# - Seberapa sering seorang pelanggan melakukan pembelian dalam beberapa bulan terakhir?
# - Berapa banyak uang yang dihabiskan pelanggan dalam beberapa bulan terakhir?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
customers_df = pd.read_csv("customers_dataset.csv")
customers_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %% [markdown]
# **Insight:**
# - Kode di atas akan menampilkan 5 baris pertama dari DataFrame customers_df

# %%
orders_df = pd.read_csv("orders_dataset.csv")
orders_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %% [markdown]
# **Insight:**
# - Kode di atas akan menampilkan 5 baris pertama dari DataFrame orders_df

# %%
products_df = pd.read_csv("products_dataset.csv")
products_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %% [markdown]
# **Insight:**
# - Kode di atas akan menampilkan 5 baris pertama dari DataFrame products_df

# %%
sellers_df = pd.read_csv("sellers_dataset.csv")
sellers_df.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %% [markdown]
# **Insight:**
# - Kode di atas akan menampilkan 5 baris pertama dari DataFrame sellers_df

# %%
order_items_df = pd.read_csv("order_items_dataset.csv")
order_items_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %% [markdown]
# **Insight:**
# - Kode di atas akan menampilkan 5 baris pertama dari DataFrame order_items_df

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# Menilai Data customers_df

# %%
customers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
customers_df.isna().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
print("Jumlah duplikasi: ", customers_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
customers_df.describe()
# Out:
#        customer_zip_code_prefix
# count              99441.000000
# mean               35137.474583
# std                29797.938996
# min                 1003.000000
# 25%                11347.000000
# 50%                24416.000000
# 75%                58900.000000
# max                99990.000000

# %% [markdown]
# **Insight:**
# -  Tidak ada masalah dengan tipe data dan jumlah data dari seluruh kolom tersebut.
# - Tidak terdapat missing values.
# - Tidak ada data yang duplikat.
# - Tidak ada inaccurate value pada kolom customer_zip_code_prefix.

# %% [markdown]
# Menilai Data orders_df

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
orders_df.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
print("Jumlah duplikasi: ", orders_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
orders_df.describe()
# Out:
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# freq                                   1                                 1
#
#        order_status order_purchase_timestamp    order_approved_at  \
# count         99441                    99441                99281
# unique            8                    98875                90733
# top       delivered      2018-04-11 10:48:14  2018-02-27 04:31:10
# freq          96478                        3                    9
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# count                         97658                         96476
# unique                        81018                         95664
# ...

# %% [markdown]
# **Insight:**
# - Terdapat sedikit perbedaan pada jumlah data pada kolom order_approved_at, order_delivered_carrier_date, dan order_delivered_customer_date. Hal ini menunjukkan adanya missing values pada kolom-kolom tersebut.
# - Terdapat kesalahan tipe data untuk kolom order_purchase_timestamp, order_approved_at, order_delivered_carrier_date, order_delivered_customer_date, dan order_estimated_delivery_date. Kelima kolom tersebut harusnya direpresentasikan sebagai tipe data datetime.
# - Terdapat 160 missing value pada kolom order_approved_at.
# - Terdapat 1783 missing value pada kolom order_delivered_carrier_date.
# - Terdapat 2965 missing value pada kolom order_delivered_customer_date.

# %% [markdown]
# Menilai Data products_df

# %%
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
products_df.isna().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
print("Jumlah duplikasi: ", products_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
products_df.describe()
# Out:
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# count         32341.000000                32341.000000        32341.000000
# mean             48.476949                  771.495285            2.188986
# std              10.245741                  635.115225            1.736766
# min               5.000000                    4.000000            1.000000
# 25%              42.000000                  339.000000            1.000000
# 50%              51.000000                  595.000000            1.000000
# 75%              57.000000                  972.000000            3.000000
# max              76.000000                 3992.000000           20.000000
#
#        product_weight_g  product_length_cm  product_height_cm  \
# count      32949.000000       32949.000000       32949.000000
# mean        2276.472488          30.815078          16.937661
# std         4282.038731          16.914458          13.637554
# ...

# %% [markdown]
# **Insight:**
# - Terdapat sedikit perbedaan pada jumlah data pada kolom product_category_name,
# product_name_lenght, product_description_lenght, product_photos_qty, product_weight_g, product_length_cm, product_height_cm, dan product_width_cm. Hal ini menunjukkan adanya missing values pada kolom-kolom tersebut.
# - Terdapat 610 missing value pada kolom product_category_name.
# - Terdapat 610 missing value pada kolomproduct_name_lenght.
# - Terdapat 610 missing value pada kolomproduct_description_lenght.
# - Terdapat 610 missing value pada kolomproduct_photos_qty.
# - Terdapat 2 missing value pada kolomproduct_weight_g.
# - Terdapat 2 missing value pada kolomproduct_length_cm.
# - Terdapat 2 missing value pada kolomproduct_height_cm.
# - Terdapat 2 missing value pada kolomproduct_width_cm.

# %% [markdown]
# Menilai Data sellers_df

# %%
sellers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   object
#  1   seller_zip_code_prefix  3095 non-null   int64
#  2   seller_city             3095 non-null   object
#  3   seller_state            3095 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 96.8+ KB

# %%
sellers_df.isna().sum()
# Out:
# seller_id                 0
# seller_zip_code_prefix    0
# seller_city               0
# seller_state              0
# dtype: int64

# %%
print("Jumlah duplikasi: ", sellers_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
sellers_df.describe()
# Out:
#        seller_zip_code_prefix
# count             3095.000000
# mean             32291.059451
# std              32713.453830
# min               1001.000000
# 25%               7093.500000
# 50%              14940.000000
# 75%              64552.500000
# max              99730.000000

# %% [markdown]
# **Insight:**
# -  Tidak ada masalah dengan tipe data dan jumlah data dari seluruh kolom tersebut.
# - Tidak terdapat missing values.
# - Tidak ada data yang duplikat.
# - Tidak ada inaccurate value pada kolom seller_zip_code_prefix.

# %% [markdown]
# Menilai Data order_items_df

# %%
order_items_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %%
order_items_df.isna().sum()
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %%
print("Jumlah duplikasi: ", order_items_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
order_items_df.describe()
# Out:
#        order_item_id          price  freight_value
# count  112650.000000  112650.000000  112650.000000
# mean        1.197834     120.653739      19.990320
# std         0.705124     183.633928      15.806405
# min         1.000000       0.850000       0.000000
# 25%         1.000000      39.900000      13.080000
# 50%         1.000000      74.990000      16.260000
# 75%         1.000000     134.900000      21.150000
# max        21.000000    6735.000000     409.680000

# %% [markdown]
# **Insight:**
# -  Tidak ada masalah dengan tipe data dan jumlah data dari seluruh kolom tersebut.
# - Tidak terdapat missing values.
# - Tidak ada data yang duplikat.
# - Tidak ada inaccurate value pada kolom price dan freight_value.

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# Membersihkan Data orders_df

# %% [markdown]
# *   Menangani missing value

# %%
orders_df[orders_df.order_approved_at.isna()]
orders_df[orders_df.order_delivered_carrier_date.isna()]
orders_df[orders_df.order_delivered_customer_date.isna()]
# Out:
#                                order_id                       customer_id  \
# 6      136cce7faa42fdb2cefd53fdc79a6098  ed0271e0b7da060a393796590e7b737a
# 44     ee64d42b8cf066f35eac1cf57de1aa85  caded193e8e47b8362864762a83db3c5
# 103    0760a852e4e9d89eb77bf631eaaf1c84  d2a79636084590b7465af8ab374a8cf5
# 128    15bed8e2fec7fdbadb186b57c46c92f2  f3f0e613e0bdb9c7cee75504f0f90679
# 154    6942b8da583c2f9957e990d028607019  52006a9383bf149a4fb24226b173106f
# ...                                 ...                               ...
# 99283  3a3cddda5a7c27851bd96c3313412840  0b0d6095c5555fe083844281f6b093bb
# 99313  e9e64a17afa9653aacf2616d94c005b8  b4cd0522e632e481f8eaf766a2646e86
# 99347  a89abace0dcc01eeb267a9660b5ac126  2f0524a7b1b3845a1a57fcf3910c4333
# 99348  a69ba794cc7deb415c3e15a0a3877e69  726f0894b5becdf952ea537d5266e543
# 99415  5fabc81b6322c8443648e1b21a6fef21  32c9df889d41b0ee8309a5efb6855dcb
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
orders_df.order_approved_at.value_counts()
# Out:
# order_approved_at
# 2018-02-27 04:31:10    9
# 2017-11-07 07:30:38    7
# 2018-02-27 04:31:01    7
# 2018-02-06 05:31:52    7
# 2017-11-07 07:30:29    7
#                       ..
# 2018-08-22 11:50:14    1
# 2017-09-22 11:27:36    1
# 2018-03-07 16:40:32    1
# 2017-08-08 10:50:15    1
# 2018-03-09 11:20:28    1
# Name: count, Length: 90733, dtype: int64

# %%
orders_df.order_delivered_carrier_date.value_counts()
# Out:
# order_delivered_carrier_date
# 2018-05-09 15:48:00    47
# 2018-05-10 18:29:00    32
# 2018-05-07 12:31:00    21
# 2018-05-02 15:15:00    16
# 2018-07-24 16:07:00    16
#                        ..
# 2018-01-03 17:37:21     1
# 2017-10-27 20:07:58     1
# 2017-11-21 18:57:37     1
# 2018-03-21 20:03:37     1
# 2018-03-09 22:11:59     1
# Name: count, Length: 81018, dtype: int64

# %%
orders_df.order_delivered_customer_date.value_counts()
# Out:
# order_delivered_customer_date
# 2018-05-08 23:38:46    3
# 2016-10-27 17:32:07    3
# 2018-02-14 21:09:19    3
# 2017-06-19 18:47:51    3
# 2018-05-08 19:36:48    3
#                       ..
# 2018-07-12 17:48:45    1
# 2018-05-18 18:24:36    1
# 2018-01-17 13:29:13    1
# 2018-06-29 11:21:34    1
# 2018-03-16 13:08:30    1
# Name: count, Length: 95664, dtype: int64

# %%
orders_df.order_approved_at.fillna(value=9, inplace=True)
# Out:
# <ipython-input-36-d0bcf5cd504b>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   orders_df.order_approved_at.fillna(value=9, inplace=True)

# %%
orders_df.order_delivered_carrier_date.fillna(value=47, inplace=True)
# Out:
# <ipython-input-37-2cf5e9198f7e>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   orders_df.order_delivered_carrier_date.fillna(value=47, inplace=True)

# %%
orders_df.order_delivered_customer_date.fillna(value=3, inplace=True)
# Out:
# <ipython-input-38-58b79efc24e9>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   orders_df.order_delivered_customer_date.fillna(value=3, inplace=True)

# %%
orders_df.isna().sum()
# Out:
# order_id                         0
# customer_id                      0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                0
# order_delivered_carrier_date     0
# order_delivered_customer_date    0
# order_estimated_delivery_date    0
# dtype: int64

# %% [markdown]
# *   Mengganti tipe data pada kolom order_purchase_timestamp, order_approved_at,
# order_delivered_carrier_date, order_delivered_customer_date, dan order_estimated_delivery_date menjadi datetime.

# %%
datetime_columns = ["order_purchase_timestamp", "order_approved_at", "order_delivered_carrier_date", "order_delivered_customer_date", "order_estimated_delivery_date"]

for column in datetime_columns:
  orders_df[column] = pd.to_datetime(orders_df[column], errors='coerce')

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  datetime64[ns]
#  4   order_approved_at              99281 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   97658 non-null  datetime64[ns]
#  6   order_delivered_customer_date  96476 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  99441 non-null  datetime64[ns]
# dtypes: datetime64[ns](5), object(3)
# memory usage: 6.1+ MB

# %% [markdown]
# **Insight:**
# - Sudah tidak terdapat missing value.
# - Kolom order_purchase_timestamp, order_approved_at,
# order_delivered_carrier_date, order_delivered_customer_date, dan order_estimated_delivery_date sudah diganti tipe data nya menjadi datetime.

# %% [markdown]
# Membersihkan Data products_df

# %% [markdown]
# * Menangani missing value

# %%
products_df[products_df.product_category_name.isna()]
products_df[products_df.product_name_lenght.isna()]
products_df[products_df.product_description_lenght.isna()]
products_df[products_df.product_photos_qty.isna()]
products_df[products_df.product_weight_g.isna()]
products_df[products_df.product_length_cm.isna()]
products_df[products_df.product_height_cm.isna()]
products_df[products_df.product_width_cm.isna()]
# Out:
#                              product_id product_category_name  \
# 8578   09ff539a621711667c43eba6a3bd8466                 bebes
# 18851  5eb564652db742ff8f28759cd8d2652a                   NaN
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 8578                  60.0                       865.0                 3.0
# 18851                  NaN                         NaN                 NaN
#
#        product_weight_g  product_length_cm  product_height_cm  \
# 8578                NaN                NaN                NaN
# 18851               NaN                NaN                NaN
#
#        product_width_cm
# 8578                NaN
# 18851               NaN

# %%
products_df.product_category_name.value_counts()
# Out:
# product_category_name
# cama_mesa_banho                  3029
# esporte_lazer                    2867
# moveis_decoracao                 2657
# beleza_saude                     2444
# utilidades_domesticas            2335
#                                  ...
# fashion_roupa_infanto_juvenil       5
# casa_conforto_2                     5
# pc_gamer                            3
# seguros_e_servicos                  2
# cds_dvds_musicais                   1
# Name: count, Length: 73, dtype: int64

# %%
products_df.product_name_lenght.value_counts()
# Out:
# product_name_lenght
# 60.0    2182
# 59.0    2025
# 58.0    1887
# 57.0    1719
# 55.0    1683
#         ...
# 66.0       1
# 72.0       1
# 67.0       1
# 76.0       1
# 6.0        1
# Name: count, Length: 66, dtype: int64

# %%
products_df.product_description_lenght.value_counts()
# Out:
# product_description_lenght
# 404.0     94
# 729.0     86
# 651.0     66
# 703.0     66
# 236.0     65
#           ..
# 2795.0     1
# 2308.0     1
# 3698.0     1
# 3522.0     1
# 2207.0     1
# Name: count, Length: 2960, dtype: int64

# %%
products_df.product_photos_qty.value_counts()
# Out:
# product_photos_qty
# 1.0     16489
# 2.0      6263
# 3.0      3860
# 4.0      2428
# 5.0      1484
# 6.0       968
# 7.0       343
# 8.0       192
# 9.0       105
# 10.0       95
# 11.0       46
# 12.0       35
# 13.0        9
# 15.0        8
# 17.0        7
# 14.0        5
# 18.0        2
# 20.0        1
# 19.0        1
# Name: count, dtype: int64

# %%
products_df.product_weight_g.value_counts()
# Out:
# product_weight_g
# 200.0     2084
# 300.0     1561
# 150.0     1259
# 400.0     1206
# 100.0     1188
#           ...
# 6075.0       1
# 822.0        1
# 631.0        1
# 2925.0       1
# 1920.0       1
# Name: count, Length: 2204, dtype: int64

# %%
products_df.product_length_cm.value_counts()
# Out:
# product_length_cm
# 16.0    5520
# 20.0    2816
# 30.0    2029
# 18.0    1502
# 25.0    1387
#         ...
# 96.0       4
# 10.0       3
# 8.0        2
# 9.0        2
# 7.0        1
# Name: count, Length: 99, dtype: int64

# %%
products_df.product_height_cm.value_counts()
# Out:
# product_height_cm
# 10.0    2548
# 15.0    2022
# 20.0    1991
# 16.0    1595
# 11.0    1551
#         ...
# 98.0       2
# 97.0       2
# 99.0       1
# 89.0       1
# 94.0       1
# Name: count, Length: 102, dtype: int64

# %%
products_df.product_width_cm.value_counts()
# Out:
# product_width_cm
# 11.0     3718
# 20.0     3053
# 16.0     2808
# 15.0     2393
# 30.0     1786
#          ...
# 103.0       1
# 86.0        1
# 98.0        1
# 87.0        1
# 104.0       1
# Name: count, Length: 95, dtype: int64

# %%
products_df.product_category_name.fillna(value="cama_mesa_banho", inplace=True)
# Out:
# <ipython-input-51-569b564854a7>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   products_df.product_category_name.fillna(value="cama_mesa_banho", inplace=True)

# %%
products_df.product_name_lenght.fillna(value=2182, inplace=True)
# Out:
# <ipython-input-52-0bf5fb92aaaa>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   products_df.product_name_lenght.fillna(value=2182, inplace=True)

# %%
products_df.product_description_lenght.fillna(value=94, inplace=True)
# Out:
# <ipython-input-53-bb2d9ffc6fde>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   products_df.product_description_lenght.fillna(value=94, inplace=True)

# %%
products_df.product_photos_qty.fillna(value=16489, inplace=True)
# Out:
# <ipython-input-54-2e46dcf2b0fc>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   products_df.product_photos_qty.fillna(value=16489, inplace=True)

# %%
products_df.product_weight_g.fillna(value=2084, inplace=True)
# Out:
# <ipython-input-55-c7fd8f641b65>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   products_df.product_weight_g.fillna(value=2084, inplace=True)

# %%
products_df.product_length_cm.fillna(value=5520, inplace=True)
# Out:
# <ipython-input-56-bb04c3c3a5f5>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   products_df.product_length_cm.fillna(value=5520, inplace=True)

# %%
products_df.product_height_cm.fillna(value=2548, inplace=True)
# Out:
# <ipython-input-57-f73cdf059186>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   products_df.product_height_cm.fillna(value=2548, inplace=True)

# %%
products_df.product_width_cm.fillna(value=3718, inplace=True)
# Out:
# <ipython-input-58-feae36658474>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   products_df.product_width_cm.fillna(value=3718, inplace=True)

# %%
products_df.isna().sum()
# Out:
# product_id                    0
# product_category_name         0
# product_name_lenght           0
# product_description_lenght    0
# product_photos_qty            0
# product_weight_g              0
# product_length_cm             0
# product_height_cm             0
# product_width_cm              0
# dtype: int64

# %% [markdown]
# **Insight:**
# - Sudah tidak terdapat missing value.

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Eksplorasi Data customers_df

# %%
customers_df.sample(5)
# Out:
#                             customer_id                customer_unique_id  \
# 3296   a63bb59ba24b8048df8549dd217a586c  d05658f0f527a8dfcaaa935a160a5094
# 78510  24e316e6677cf2d79c36e9d56314926a  c6e9898e783e5d990c462199a8314ba8
# 3059   bab91c3c25a207c83b5c95392df95163  7d5c4bcaf5e9ce14f2ac132ed39b1bb2
# 37300  554df975298823cc6dec4fe5334583e6  80612c407e8897e64a8e8ec4dbfa9fc6
# 39309  8c0993c9db15910b863ce755731f3b6f  1483a22260e8aead5b0119eab451680f
#
#        customer_zip_code_prefix    customer_city customer_state
# 3296                       8740  mogi das cruzes             SP
# 78510                      6243           osasco             SP
# 3059                       5890        sao paulo             SP
# 37300                     45656           ilheus             BA
# 39309                     45651           ilheus             BA

# %%
customers_df.describe(include="all")
# Out:
#                              customer_id                customer_unique_id  \
# count                              99441                             99441
# unique                             99441                             96096
# top     06b8999e2fba1a1fbc88172c00ba8bc7  8d50f5eadf50201ccdcedfb9e2ac8455
# freq                                   1                                17
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         customer_zip_code_prefix customer_city customer_state
# ...

# %%
customers_df.customer_id.is_unique
# Out:
# True

# %%
customers_df.groupby(by="customer_city").customer_id.nunique().sort_values(ascending=False)
# Out:
# customer_city
# sao paulo         15540
# rio de janeiro     6882
# belo horizonte     2773
# brasilia           2131
# curitiba           1521
#                   ...
# ibiara                1
# rio espera            1
# rio dos indios        1
# rio dos cedros        1
# lagoao                1
# Name: customer_id, Length: 4119, dtype: int64

# %%
customers_df.groupby(by="customer_state").customer_id.nunique().sort_values(ascending=False)
# Out:
# customer_state
# SP    41746
# RJ    12852
# MG    11635
# RS     5466
# PR     5045
# SC     3637
# BA     3380
# DF     2140
# ES     2033
# GO     2020
# PE     1652
# CE     1336
# PA      975
# MT      907
# MA      747
# MS      715
# PB      536
# PI      495
# RN      485
# AL      413
# SE      350
# TO      280
# RO      253
# AM      148
# AC       81
# AP       68
# RR       46
# Name: customer_id, dtype: int64

# %% [markdown]
# **Insight:**
# - Pelanggan paling banyak berada di kota Sao Paulo dengan jumlah 15540. Selain itu, pelanggan paling banyak berasal dari negara bagian SP dengan jumlah 41746.

# %% [markdown]
# ### Eksplorasi Data orders_df

# %%
delivery_time = orders_df["order_delivered_customer_date"] - orders_df["order_approved_at"]
delivery_time = delivery_time.apply(lambda x: x.total_seconds())
orders_df["delivery_time"] = round(delivery_time/86400)

# %%
orders_df.sample(5)
# Out:
#                                order_id                       customer_id  \
# 60948  82c08d39d308cb94bad8fc71b0b7b257  ee3424ba724cb6d97ba9785339bb5ea5
# 45790  92b7ad3b562646f9112aa21df37f790b  c9da69edb9b3c5e7b8074ac4ea9b2244
# 50803  7dbd3edac8e390bcdc58a0760d1ad229  434dee65d973593dbb8461ba38202798
# 63691  4130baec40bb0cf5872d8c322e6383d5  b74e4b5a94ada60313382c04f7f97ab5
# 21231  2beb8dc5dc4936b846fb058ecad3bfc2  e9c2696343754fa3251902af0fb408c8
#
#       order_status order_purchase_timestamp   order_approved_at  \
# 60948    delivered      2017-06-30 11:07:59 2017-06-30 11:23:38
# 45790    delivered      2018-08-20 19:02:22 2018-08-21 19:06:08
# 50803    delivered      2018-03-13 21:13:52 2018-03-15 03:29:34
# 63691    delivered      2018-04-06 21:51:47 2018-04-06 22:09:29
# 21231    delivered      2018-03-13 23:06:11 2018-03-14 00:00:27
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 60948          2017-06-30 15:32:12           2017-07-10 16:22:36
# ...

# %%
orders_df.describe(include="all")
# Out:
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# freq                                   1                                 1
# mean                                 NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
# std                                  NaN                               NaN
#
#        order_status       order_purchase_timestamp  \
# ...

# %% [markdown]
# **Insight:**
# - Bisa membuat sebuah kolom baru untuk memuat waktu pengiriman tiap order berdasarkan data pada kolom order_approved_at dan order_delivered_customer_date.
# - Rata-rata waktu pengiriman sebesar 12 hari.

# %% [markdown]
# ### Eksplorasi Data orders_df dan customers_df

# %%
orders_customers_df = pd.merge(
    left=orders_df,
    right=customers_df,
    how="left",
    left_on="customer_id",
    right_on="customer_id"
)
orders_customers_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
orders_customers_df.groupby(by="customer_city").order_id.nunique().sort_values(ascending=False).reset_index().head(10)
# Out:
#            customer_city  order_id
# 0              sao paulo     15540
# 1         rio de janeiro      6882
# 2         belo horizonte      2773
# 3               brasilia      2131
# 4               curitiba      1521
# 5               campinas      1444
# 6           porto alegre      1379
# 7               salvador      1245
# 8              guarulhos      1189
# 9  sao bernardo do campo       938

# %%
orders_customers_df.groupby(by="customer_state").order_id.nunique().sort_values(ascending=False)
# Out:
# customer_state
# SP    41746
# RJ    12852
# MG    11635
# RS     5466
# PR     5045
# SC     3637
# BA     3380
# DF     2140
# ES     2033
# GO     2020
# PE     1652
# CE     1336
# PA      975
# MT      907
# MA      747
# MS      715
# PB      536
# PI      495
# RN      485
# AL      413
# SE      350
# TO      280
# RO      253
# AM      148
# AC       81
# AP       68
# RR       46
# Name: order_id, dtype: int64

# %% [markdown]
# **Insight:**
# -  Diketahui bahwa kota Sao Paulo	dan	Rio de Daneiro merupakan dua kota yang memiliki jumlah order terbanyak.
# - Diketahui bahwa SP merupakan state yang balik banyak melakukan order.

# %% [markdown]
# ### Eksplorasi Data products_df dan order_items_df

# %%
products_df.describe(include="all")
# Out:
#                               product_id product_category_name  \
# count                              32951                 32951
# unique                             32951                    73
# top     1e9e8ef04dbcff4541ed26657ea517e5       cama_mesa_banho
# freq                                   1                  3639
# mean                                 NaN                   NaN
# std                                  NaN                   NaN
# min                                  NaN                   NaN
# 25%                                  NaN                   NaN
# 50%                                  NaN                   NaN
# 75%                                  NaN                   NaN
# max                                  NaN                   NaN
#
#         product_name_lenght  product_description_lenght  product_photos_qty  \
# count          32951.000000                32951.000000        32951.000000
# ...

# %%
order_items_df.describe(include="all")
# Out:
#                                 order_id  order_item_id  \
# count                             112650  112650.000000
# unique                             98666            NaN
# top     8272b63d03f5f79c56e9e4120aec44ef            NaN
# freq                                  21            NaN
# mean                                 NaN       1.197834
# std                                  NaN       0.705124
# min                                  NaN       1.000000
# 25%                                  NaN       1.000000
# 50%                                  NaN       1.000000
# 75%                                  NaN       1.000000
# max                                  NaN      21.000000
#
#                               product_id                         seller_id  \
# count                             112650                            112650
# unique                             32951                              3095
# ...

# %%
order_products_df = pd.merge(
    left=order_items_df,
    right=products_df,
    how="left",
    left_on="product_id",
    right_on="product_id"
)
order_products_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value product_category_name  \
# 0  2017-09-19 09:45:35   58.90          13.29            cool_stuff
# 1  2017-05-03 11:05:13  239.90          19.93              pet_shop
# ...

# %%
order_products_df.sort_values(by="price", ascending=False)
# Out:
#                                 order_id  order_item_id  \
# 3556    0812eb902a67711a1cb742b3cdaa65ae              1
# 112233  fefacc66af859508bf1a7934eab1e97f              1
# 107841  f5136e38d1a14a4dbd87dff67da82701              1
# 74336   a96610ab360d42a2e5335a3998b4718a              1
# 11249   199af31afc78c699f0dbf71fb178d4d4              1
# ...                                  ...            ...
# 57304   8272b63d03f5f79c56e9e4120aec44ef              8
# 57300   8272b63d03f5f79c56e9e4120aec44ef              4
# 48625   6e864b3f0ec71031117ad4cf46b7f2a1              1
# 27652   3ee6513ae7ea23bdfab5b9ab60bffcb5              1
# 87081   c5bdd8ef3c0ec420232e668302179113              2
#
#                               product_id                         seller_id  \
# 3556    489ae2aa008f021502940f251d4cce7f  e3b4998c7a498169dc7bce44e6bb6277
# 112233  69c590f7ffc7bf8db97190b6cb6ed62e  80ceebb4ee9b31afb6c6a916a574a1e2
# ...

# %%
order_products_df.groupby(by="product_category_name").agg({
    "seller_id": "nunique",
    "price": "sum",
    "freight_value": "sum"
}).sort_values(by="price", ascending=False)
# Out:
#                                seller_id       price  freight_value
# product_category_name
# beleza_saude                         492  1258681.34      182566.73
# cama_mesa_banho                      431  1216523.96      232862.85
# relogios_presentes                   101  1205005.68      100535.93
# esporte_lazer                        481   988048.97      168607.51
# informatica_acessorios               287   911954.32      147318.08
# ...                                  ...         ...            ...
# flores                                 3     1110.04         488.87
# casa_conforto_2                        4      760.27         410.31
# cds_dvds_musicais                      1      730.00         224.99
# fashion_roupa_infanto_juvenil          4      569.85          95.51
# seguros_e_servicos                     2      283.29          41.22
#
# [73 rows x 3 columns]

# %% [markdown]
# **Insight:**
# - Berdasarkan pivot table di atas, diketahui bahwa kategori beleza_saude merupakan produk yang paling laris dan nilai produk paling banyak berada di kategori cama_mesa_banho.

# %% [markdown]
# ### Eksplorasi Data all_df

# %%
all_df = pd.merge(
    left=order_products_df,
    right=orders_customers_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
all_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value product_category_name  \
# 0  2017-09-19 09:45:35   58.90          13.29            cool_stuff
# 1  2017-05-03 11:05:13  239.90          19.93              pet_shop
# ...

# %%
all_df.groupby(by=["customer_city", "product_category_name"]).agg({
    "price": "sum",
    "freight_value": "sum"
})
# Out:
#                                              price  freight_value
# customer_city       product_category_name
# abadia dos dourados cool_stuff              199.00          20.63
#                     esporte_lazer           120.00          15.59
#                     livros_interesse_geral   39.90          18.38
# abadiania           eletroportateis         949.99          75.53
# abaete              bebes                    65.00          17.70
# ...                                            ...            ...
# ze doca             esporte_lazer           149.90          38.60
#                     ferramentas_jardim       39.90          26.61
#                     instrumentos_musicais   359.00          49.04
# zortea              cama_mesa_banho          29.90          16.79
#                     informatica_acessorios   69.90          20.98
#
# [25350 rows x 2 columns]

# %%
all_df.groupby(by=["customer_city", "product_category_name"]).agg({
    "price": "sum",
    "freight_value": "sum"
}).sort_values(by="price", ascending=False)
# Out:
#                                                         price  freight_value
# customer_city    product_category_name
# sao paulo        cama_mesa_banho                    199480.15       32614.01
#                  beleza_saude                       189361.87       22791.56
#                  relogios_presentes                 165897.46        9723.36
#                  informatica_acessorios             144635.68       16635.46
#                  esporte_lazer                      144533.26       19955.80
# ...                                                       ...            ...
# tupa             construcao_ferramentas_construcao       3.99          12.79
# caldas novas     fashion_underwear_e_moda_praia          3.90          15.10
# palmeira d'oeste informatica_acessorios                  3.90          11.85
# extrema          musica                                  3.85           7.71
# hortolandia      construcao_ferramentas_construcao       0.85          18.23
#
# ...

# %% [markdown]
# **Insight:**
# - Pivot table di atas memberikan gambaran terkait kategori produk yang disukai pengguna berdasarkan lokasi kota pelanggan. Jika diperhatikan, kategori produk esporte_lazer paling banyak terjual pada kota abadia dos dourados dan ze doca.
# - Kategori produk cama_mesa_banho dengan harga termahal banyak terjual di kota Sao Paulo.

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Kategori Produk Apa yang Paling Mahal dan Paling Murah?

# %%
sum_order_products_df = all_df.groupby("product_category_name").price.sum().sort_values(ascending=False).reset_index()
sum_order_products_df.head(15)
# Out:
#      product_category_name       price
# 0             beleza_saude  1258681.34
# 1          cama_mesa_banho  1216523.96
# 2       relogios_presentes  1205005.68
# 3            esporte_lazer   988048.97
# 4   informatica_acessorios   911954.32
# 5         moveis_decoracao   729762.49
# 6               cool_stuff   635290.85
# 7    utilidades_domesticas   632248.66
# 8               automotivo   592720.11
# 9       ferramentas_jardim   485256.46
# 10              brinquedos   483946.60
# 11                   bebes   411764.89
# 12              perfumaria   399124.87
# 13               telefonia   323667.53
# 14       moveis_escritorio   273960.70

# %%
sum_order_products_df = all_df.groupby("product_category_name").price.sum().sort_values(ascending=False).reset_index()
sum_order_products_df.head(15)

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(24, 6))

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(24, 6))

colors = ["#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3"]

sns.barplot(x="price", y="product_category_name", data=sum_order_products_df.head(5), palette=colors, ax=ax[0])
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title("Expensive Product", loc="center", fontsize=15)
ax[0].tick_params(axis ='y', labelsize=12)

sns.barplot(x="price", y="product_category_name", data=sum_order_products_df.sort_values(by="price", ascending=True).head(5), palette=colors, ax=ax[1])
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].invert_xaxis()
ax[1].yaxis.set_label_position("right")
ax[1].yaxis.tick_right()
ax[1].set_title("Cheap Product", loc="center", fontsize=15)
ax[1].tick_params(axis='y', labelsize=12)

plt.suptitle("Expensive and Cheap Product", fontsize=20)
plt.show()
# Out:
# <ipython-input-90-78c79b516c17>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="price", y="product_category_name", data=sum_order_products_df.head(5), palette=colors, ax=ax[0])
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %% [markdown]
# **Insight:**
# - Kategori produk termahal adalah beleza saude.
# - Kategori produk termurah adalah seguros e servicos.

# %% [markdown]
# ### Pertanyaan 2: Bagaimana Penyebaran Pelanggan berdasarkan Kota dari E-Commerce tersebut?

# %%
top_n = 15
bycity_df = bycity_df.sort_values(by="customer_count", ascending=False).head(top_n)

plt.figure(figsize=(12, 8))

colors_ = ["#72BCD4"] * top_n

sns.barplot(
    x="customer_count",
    y="customer_city",
    data=bycity_df,
    palette=colors_
)

plt.title("Number of Customers by City", loc="center", fontsize=15)
plt.ylabel(None)
plt.xlabel("Customer Count")
plt.tick_params(axis='y', labelsize=12)

plt.show()
# Out:
# <ipython-input-95-0b87abc1e2a7>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %% [markdown]
# **Insight:**
# -  Pelanggan yang terbanyak berasal dari kota Sao Paoulo.

# %% [markdown]
# ### RFM Analysis

# %%
orders_df["order_approved_at"] = pd.to_datetime(orders_df["order_approved_at"], errors='coerce')

rfm_df = all_df.groupby(by="customer_id", as_index=False).agg({
    "order_approved_at": "max",  # mengambil tanggal order terakhir
    "order_id": "nunique",  # menghitung jumlah order
    "price": "sum"  # menghitung jumlah harga yang dihasilkan
})
rfm_df.columns = ["customer_id", "max_order_timestamp", "frequency", "monetary"]

rfm_df["max_order_timestamp"] = rfm_df["max_order_timestamp"].dt.date
recent_date = orders_df["order_approved_at"].dropna().dt.date.max()

min_order_date = rfm_df["max_order_timestamp"].dropna().min()
rfm_df["max_order_timestamp"] = rfm_df["max_order_timestamp"].fillna(min_order_date)

rfm_df["recency"] = rfm_df["max_order_timestamp"].apply(lambda x: (recent_date - x).days)

rfm_df.drop("max_order_timestamp", axis=1, inplace=True)
rfm_df.head()
# Out:
#                         customer_id  frequency  monetary  recency
# 0  00012a2ce6f8dcda20d059ce98491703          1     89.80      293
# 1  000161a058600d5901f007fab4c27140          1     54.90      414
# 2  0001fd6190edaaf884bcaf3d49edf079          1    179.99      552
# 3  0002414f95344307404f0ace7a26f1d5          1    149.90      382
# 4  000379cdec625522490c315e70c7a9fb          1     93.00      152

# %%
# Create a 3-row and 1-column layout
fig, ax = plt.subplots(nrows=3, ncols=1, figsize=(10, 18))  # Adjust nrows to 3

# Define color palette
colors = ["#72BCD4", "#72BCD4", "#72BCD4"]

# Recency plot with top 3 customers
sns.barplot(y="recency", x="customer_id", data=rfm_df.sort_values(by="recency", ascending=True).head(2), palette=colors, ax=ax[0])
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title("By Recency (days)", loc="center", fontsize=18)
ax[0].tick_params(axis='x', labelsize=12)

# Frequency plot with top 3 customers
sns.barplot(y="frequency", x="customer_id", data=rfm_df.sort_values(by="frequency", ascending=False).head(2), palette=colors, ax=ax[1])
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].set_title("By Frequency", loc="center", fontsize=18)
ax[1].tick_params(axis='x', labelsize=12)

# Monetary plot with top 3 customers
sns.barplot(y="monetary", x="customer_id", data=rfm_df.sort_values(by="monetary", ascending=False).head(2), palette=colors, ax=ax[2])
ax[2].set_ylabel(None)
ax[2].set_xlabel(None)
ax[2].set_title("By Monetary", loc="center", fontsize=18)
ax[2].tick_params(axis='x', labelsize=12)

# Adjust the overall title
plt.suptitle("Best Customer Based on RFM Parameters (customer_id)", fontsize=20)
plt.tight_layout(rect=[0, 0, 1, 0.96])  # Adjust layout to fit the title
plt.show()
# Out:
# <ipython-input-120-4921ba1243d3>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y="recency", x="customer_id", data=rfm_df.sort_values(by="recency", ascending=True).head(2), palette=colors, ax=ax[0])
# <ipython-input-120-4921ba1243d3>:8: UserWarning: The palette list has more values (3) than needed (2), which may not be intended.
#   sns.barplot(y="recency", x="customer_id", data=rfm_df.sort_values(by="recency", ascending=True).head(2), palette=colors, ax=ax[0])
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %% [markdown]
# **Insight:**
# - Dari visualisasi data di atas, dapat dilihat beberapa pelanggan terbaik berdasarkan ketiga parameter RFM tersebut.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - **Conclution pertanyaan 1**
#
#   Berdasarkan analisis data, kategori produk beleza saude (kecantikan dan kesehatan) merupakan kategori produk dengan harga tertinggi, sedangkan kategori seguros e servicos (asuransi dan layanan) memiliki harga terendah. Hal ini menunjukkan bahwa produk kecantikan dan kesehatan mungkin memiliki kualitas premium atau target pasar yang lebih spesifik, sementara asuransi dan layanan mungkin lebih terjangkau atau dalam bentuk jasa yang tidak membutuhkan banyak biaya produksi.
# - **Conclution pertanyaan 2**
#
#   Sebagian besar pelanggan dari e-commerce ini berasal dari kota Sao Paulo. Ini menunjukkan bahwa e-commerce tersebut memiliki jangkauan pasar yang kuat di kota metropolitan terbesar di Brasil. Dengan demikian, kota ini menjadi fokus utama dalam pemasaran, promosi, dan distribusi. Selain itu, ini bisa menjadi peluang bagi perusahaan untuk memperluas penetrasi pasar ke kota-kota lain di Brasil.
# - **Conclution RFM Analysis (pertanyaan 3, 4, 5)**
#
#   Berdasarkan analisis RFM (Recency, Frequency, Monetary), beberapa pelanggan dapat diidentifikasi sebagai pelanggan terbaik. Pelanggan yang memiliki nilai recency rendah adalah mereka yang baru-baru ini melakukan transaksi, pelanggan dengan frequency tinggi menunjukkan loyalitas karena sering berbelanja, dan pelanggan dengan monetary tinggi menunjukkan mereka menghabiskan banyak uang untuk transaksi di e-commerce tersebut. Ini mengindikasikan bahwa perusahaan dapat memprioritaskan pelanggan ini dalam strategi retention atau loyalitas, karena mereka adalah pelanggan yang berharga bagi bisnis.

# %%
all_df.to_csv("all_data.csv", index=False)
